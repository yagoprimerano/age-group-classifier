# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier 
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.svm import LinearSVC
import nltk
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import RFECV, RFE, SelectKBest
from sklearn.compose import ColumnTransformer
from sklearn.metrics import accuracy_score
import numpy as np
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn import set_config
set_config(display='diagram')
from sklearn.svm import SVC
import datetime
from sklearn.ensemble import StackingClassifier

import shap

# %%
#imports
from time import time
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.svm import SVC
#from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
import optuna
from sklearn.metrics import f1_score

# %%
import pandas as pd 

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import MaxAbsScaler
from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import  classification_report
from sklearn.feature_selection import SelectPercentile
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

# %%
import eli5

# %% [markdown]
# # Carregamento dos dados

# %%
data = pd.read_csv('../../../../data/processed/(CORRIGIDO)ep2_pln_train_pos_pt_core_news_lg.xlsx')
data.drop(['Unnamed: 0'], axis=1, inplace=True)
data.head()
# Out:
#                                             req_text age  \
# 0  - Quantos empregados em cada um dos atuais nív...  a2
# 1  - Solicito cópia das Atas do Conselho de Admin...  a2
# 2  - Solicito informar a norma (lei, decreto, por...  a2
# 3  - Solicito por gentileza, a informação sobre a...  a2
# 4  - Solicito por gentileza, a informação sobre a...  a2
#
#                                                  pos
# 0  PUNCT DET NOUN ADP DET NUM ADP ADJ NOUN ADJ PU...
# 1  PUNCT VERB NOUN ADP PROPN ADP PROPN ADP NOUN A...
# 2  PUNCT VERB VERB DET NOUN PUNCT NOUN PUNCT NOUN...
# 3  PUNCT VERB ADP NOUN PUNCT DET NOUN ADP DET NOU...
# 4  PUNCT VERB ADP NOUN PUNCT DET NOUN ADP DET NOU...

# %%
data['age'] = data['age'].map({
                                'a4':3,
                                'a3': 2,
                                'a2': 1,
                                'a1': 0})

# %%
data.head()
# Out:
#                                             req_text  age  \
# 0  - Quantos empregados em cada um dos atuais nív...    1
# 1  - Solicito cópia das Atas do Conselho de Admin...    1
# 2  - Solicito informar a norma (lei, decreto, por...    1
# 3  - Solicito por gentileza, a informação sobre a...    1
# 4  - Solicito por gentileza, a informação sobre a...    1
#
#                                                  pos
# 0  PUNCT DET NOUN ADP DET NUM ADP ADJ NOUN ADJ PU...
# 1  PUNCT VERB NOUN ADP PROPN ADP PROPN ADP NOUN A...
# 2  PUNCT VERB VERB DET NOUN PUNCT NOUN PUNCT NOUN...
# 3  PUNCT VERB ADP NOUN PUNCT DET NOUN ADP DET NOU...
# 4  PUNCT VERB ADP NOUN PUNCT DET NOUN ADP DET NOU...

# %%
# a seguir os dados serão divididos entre features (X) e label (y)
X_text = data['req_text'] # features
y = data['age'] # label

# %%
X_train, X_test, y_train, y_test = train_test_split(X_text, y, test_size=0.2, random_state=42,
                                                   stratify=y)

# %% [markdown]
# # Declaração do classificador

# %%
best_params = {'vect__ngram_range': (1, 3),
               'selection__percentile': 100,
               'estimator__fit_prior': False,
               'estimator__alpha': 0.3}

# %%
pipeline = Pipeline([
                ('vect', TfidfVectorizer()),
                ('scaling', MaxAbsScaler()), 
                ('selection', SelectPercentile()),
                ('estimator', MultinomialNB())
                ])

# %%
clf = pipeline.set_params(**best_params)

# %%
clf.get_params
# Out:
# <bound method Pipeline.get_params of Pipeline(steps=[('vect', TfidfVectorizer(ngram_range=(1, 3))),
#                 ('scaling', MaxAbsScaler()),
#                 ('selection', SelectPercentile(percentile=100)),
#                 ('estimator', MultinomialNB(alpha=0.3, fit_prior=False))])>

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vect', TfidfVectorizer(ngram_range=(1, 3))),
#                 ('scaling', MaxAbsScaler()),
#                 ('selection', SelectPercentile(percentile=100)),
#                 ('estimator', MultinomialNB(alpha=0.3, fit_prior=False))])

# %% [markdown]
# # Interpretabilidade

# %% [markdown]
# ## Interpretação global

# %% [markdown]
# ### Features preditivas mais relevantes

# %%
def show_most_informative_features(n=20):
    vectorizer = clf['vect']
    classifier = clf['estimator']
    feature_names = vectorizer.get_feature_names()
    coefs_with_fns = sorted(zip(classifier.coef_[0], feature_names))
    top = zip(coefs_with_fns[:n], coefs_with_fns[:-(n + 1):-1])
    print ("\tfeatures preditivas menos relevantes\tfeatures preditivas mais relevantes")
    print ("\t------------------------------------\t------------------------------------")
    for (coef_1, fn_1), (coef_2, fn_2) in top:
        print ("\t%.4f\t%-15s\t\t%.4f\t%-15s" % (coef_1, fn_1, coef_2, fn_2))

# %%
show_most_informative_features()
# Out:
# Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
# 	features preditivas menos relevantes	features preditivas mais relevantes
# 	------------------------------------	------------------------------------
# 	-13.7052	00 000         		-6.9856	de
# 	-13.7052	00 000 00      		-7.1112	boa
# 	-13.7052	00 0000        		-7.3714	gostaria
# 	-13.7052	00 0000 df     		-7.4281	para
# 	-13.7052	00 00091       		-7.4365	gostaria de
# 	-13.7052	00 00091 006677		-7.6178	tarde
# 	-13.7052	00 04parcelas  		-7.6239	boa tarde
# 	-13.7052	00 04parcelas de		-7.6257	do
# 	-13.7052	00 150         		-7.6675	da
# 	-13.7052	00 150 00      		-7.7278	no
# 	-13.7052	00 16          		-7.8663	em
# 	-13.7052	00 16 20       		-7.8763	que
# 	-13.7052	00 180         		-7.8920	de saber
# 	-13.7052	00 180 00      		-7.9077	gostaria de saber
# 	-13.7052	00 20          		-7.9559	na
# 	-13.7052	00 20 36       		-7.9949	noite
# 	-13.7052	00 20 45       		-7.9962	boa noite
# 	-13.7052	00 24          		-8.0362	se
# 	-13.7052	00 24 00       		-8.0399	saber
# 	-13.7052	00 277         		-8.2023	com
# Attribute `coef_` was deprecated in version 0.24 and will be removed in 1.1 (renaming of 0.26).

# %% [markdown]
# ### Bar plot

# %%
def make_predictions(X_test):
    
    preds = clf.predict(X_test)
    
    return preds

masker = shap.maskers.Text(tokenizer=r"\W+")
explainer = shap.Explainer(make_predictions, masker=masker)

shap_values_global = explainer(X_text)
# Out:
# PartitionExplainer explainer:  10%|████▋                                          | 808/8200 [46:06<8:05:38,  3.94s/it]
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer:  11%|█████▏                                         | 902/8200 [50:45<6:47:58,  3.35s/it]

# %%
shap.plots.bar(shap_values.mean(0))

# %% [markdown]
# ### Matriz de confusão

# %%
# Faça previsões no conjunto de teste
y_pred = clf.predict(X_test)

# Crie a matriz de confusão
conf_matrix = confusion_matrix(y_test, y_pred)

# Crie um heatmap usando seaborn
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='viridis', cbar=True,
            xticklabels=['a0', 'a1', 'a2', 'a3'],
            yticklabels=['a0', 'a1', 'a2', 'a3'])

plt.title('Matriz de Confusão')
plt.xlabel('Valores Preditos')
plt.ylabel('Valores Reais')
plt.show()

# %% [markdown]
# ### Curva ROC

# %%
# Obtenha as probabilidades previstas para cada classe no conjunto de teste
y_score = clf.predict_proba(X_test)

# Binarize as classes para a construção da curva ROC
y_test_bin = label_binarize(y_test, classes=np.unique(y))

# Calcule a curva ROC para cada classe
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(len(np.unique(y))):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

classes = ['a0', 'a1', 'a2', 'a3']

# Plote a curva ROC para cada classe
plt.figure(figsize=(8, 8))
for i in range(len(np.unique(y))):
    plt.plot(fpr[i], tpr[i], lw=2, label=f'Classe {classes[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taxa de Falso Positivo (FPR)')
plt.ylabel('Taxa de Verdadeiro Positivo (TPR)')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Classification Report

# %%
# Faça previsões no conjunto de teste
y_pred = clf.predict(X_test)

# Gere e imprima o relatório de classificação
report = classification_report(y_test, y_pred)
print("Relatório de Classificação:")
print(report)

# %% [markdown]
# ## Interpretação local

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %% [markdown]
# ### Análise para cada classe

# %%
shap_values_local = explainer(X_test[0:20])
# Out:
# PartitionExplainer explainer: 6it [00:14,  7.43s/it]

# %% [markdown]
# ### Text plot

# %%
shap.text_plot(shap_values_local)
# Out:
#     <br>
#     <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
#     <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
#     </div>
#                 <svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="41.37086895202767%" y1="33" x2="41.37086895202767%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="41.37086895202767%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1</text><line x1="21.787025661127%" y1="33" x2="21.787025661127%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="21.787025661127%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="60.954712242928345%" y1="33" x2="60.954712242928345%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="60.954712242928345%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">2</text><line x1="80.53855553382903%" y1="33" x2="80.53855553382903%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="80.53855553382903%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">3</text><line x1="21.787025661127%" y1="33" x2="21.787025661127%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="21.787025661127%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="21.787025661127%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="21.787025661127%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="80.53855553382903%" y1="33" x2="80.53855553382903%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="80.53855553382903%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">3</text><text x="80.53855553382903%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">3</text><text x="80.53855553382903%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px"></tspan>(inputs)</text><rect x="10.46511625857505%" width="70.07343927525397%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="73.19461429974126%" x2="80.53855553382903%" y1="60" y2="60" id="_fb_flvtlrkkmfgcecoevniy_ind_5" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="76.86658491678514%" y="71" font-size="12px" id="_fs_flvtlrkkmfgcecoevniy_ind_5" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.375</text><svg x="73.19461429974126%" y="40" height="20" width="7.343941234087765%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">JUNTO</text>  </svg></svg><line x1="67.99265592559577%" x2="73.19461429974126%" y1="60" y2="60" id="_fb_flvtlrkkmfgcecoevniy_ind_39" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="70.59363511266852%" y="71" font-size="12px" id="_fs_flvtlrkkmfgcecoevniy_ind_39" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.266</text><svg x="67.99265592559577%" y="40" height="20" width="5.201958374145491%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">PRECISAMOS</text>  </svg></svg><line x1="63.096695102870605%" x2="67.99265592559577%" y1="60" y2="60" id="_fb_flvtlrkkmfgcecoevniy_ind_12" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opac ...

# %% [markdown]
# ### Bar plot

# %%
shap.plots.bar(shap_values_local)

# %%
def make_predictions(X_batch_text):
    
    preds = xgb.predict(X_batch_text)
    
    return preds

masker = shap.maskers.Text(tokenizer=r"\W+")
explainer = shap.Explainer(make_predictions, masker=masker)

shap_values = explainer(X_test[1:3])

# %%
shap.text_plot(shap_values)
# Out:
#     <br>
#     <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
#     <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
#     </div>
#                 <svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="59.00900890268646%" y1="33" x2="59.00900890268646%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="59.00900890268646%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">2</text><line x1="40.990990917133345%" y1="33" x2="40.990990917133345%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="40.990990917133345%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1</text><line x1="22.972972931580223%" y1="33" x2="22.972972931580223%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="22.972972931580223%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="77.02702688823959%" y1="33" x2="77.02702688823959%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.02702688823959%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">3</text><line x1="77.02702688823959%" y1="33" x2="77.02702688823959%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.02702688823959%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">3</text><text x="77.02702688823959%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">3</text><text x="77.02702688823959%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="59.00900890268646%" y1="33" x2="59.00900890268646%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="59.00900890268646%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">2</text><text x="59.00900890268646%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">2</text><text x="59.00900890268646%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px"></tspan>(inputs)</text><rect x="53.65990981322538%" width="5.349099089461082%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="57.60135124756513%" x2="59.00900890268646%" y1="60" y2="60" id="_fb_rioglsffrwsmknxblnqd_ind_30" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="58.30518007512579%" y="71" font-size="12px" id="_fs_rioglsffrwsmknxblnqd_ind_30" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.078</text><svg x="57.60135124756513%" y="40" height="20" width="1.4076576551213336%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">comprometido</text>  </svg></svg><line x1="56.47522512346806%" x2="57.60135124756513%" y1="60" y2="60" id="_fb_rioglsffrwsmknxblnqd_ind_35" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="57.03828818551659%" y="71" font-size="12px" id="_fs_rioglsffrwsmknxblnqd_ind_35" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.062</text><svg x="56.47522512346806%" y="40" height="20" width="1.1261261240970697%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">poderá</text>  </svg></svg><line x1="55.63063053039525%" x2="56.47522512346806%" y1="60" y2="60" id="_fb_rioglsffrwsmknxblnqd_ind_31" style="stroke:rgb(255.0, 0.0, 81.08083606031 ...

# %% [markdown]
# # LIME

# %%
from lime import lime_text
from lime.lime_text import LimeTextExplainer

# %%
class_names=list(data.age.unique()) ###
explainer = LimeTextExplainer(class_names=class_names)

idx = 3
exp = explainer.explain_instance(X_test[idx], xgb.predict_proba, num_features=6, labels=[1, 4])
print('Document id: %d' % idx)
print('Predicted class =', class_names[logreg.predict(test_vectors[idx]).reshape(1,-1)[0,0]])
print('True class: %s' % class_names[y_test[idx]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7236\3105315371.py in <module>
#       3
#       4 idx = 3
# ----> 5 exp = explainer.explain_instance(X_test_text[idx], xgb.predict_proba, num_features=6, labels=[1, 4])
#       6 print('Document id: %d' % idx)
#       7 print('Predicted class =', class_names[logreg.predict(test_vectors[idx]).reshape(1,-1)[0,0]])
#
# D:\Downloads2\Anaconda\download\lib\site-packages\lime\lime_text.py in explain_instance(self, text_instance, classifier_fn, labels, top_labels, num_features, num_samples, distance_metric, model_regressor)
#     427             (ret_exp.intercept[label],
#     428              ret_exp.local_exp[label],
# --> 429              ret_exp.score, ret_exp.local_pred) = self.base.explain_instance_with_data(
#     430                 data, yss, distances, label, num_features,
#     431                 model_regressor=model_regressor,
#
# D:\Downloads2\Anaconda\download\lib\site-packages\lime\lime_base.py in explain_instance_with_data(self, neighborhood_data, neighborhood_labels, distances, label, num_features, feature_selection, model_regressor)
#     181         weights = self.kernel_fn(distances)
#     182         labels_column = neighborhood_labels[:, label]
# --> 183         used_features = self.feature_selection(neighborhood_data,
#     184                                                labels_column,
#     185                                                weights,
#
# D:\Downloads2\Anaconda\download\lib\site-packages\lime\lime_base.py in feature_selection(self, data, labels, weights, num_features, method)
#     132             else:
#     133                 n_method = 'highest_weights'
# --> 134             return self.feature_selection(data, labels, weights,
#     135                                           num_features, n_method)
#     136
#
# D:\Downloads2\Anaconda\download\lib\site-packages\lime\lime_base.py in feature_selection(self, data, labels, weights, num_features, method)
#      74             return np.array(range(data.shape[1]))
#      75         elif method == 'forward_selection':
# ---> 76             return self.forward_selection(data, labels, weights, num_features)
#      77         elif method == 'highest_weights':
#      78             clf = Ridge(alpha=0.01, fit_intercept=True,
#
# D:\Downloads2\Anaconda\download\lib\site-packages\lime\lime_base.py in forward_selection(self, data, labels, weights, num_features)
#      57                 if feature in used_features:
#      58                     continue
# ---> 59                 clf.fit(data[:, used_features + [feature]], labels,
#      60                         sample_weight=weights)
#      61                 score = clf.score(data[:, used_features + [feature]],
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\linear_model\_ridge.py in fit(self, X, y, sample_weight)
#    1009             y_numeric=True,
#    1010         )
# -> 1011         return super().fit(X, y, sample_weight=sample_weight)
#    1012
#    1013
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\linear_model\_ridge.py in fit(self, X, y, sample_weight)
#     780                 params = {}
#     781
# --> 782             self.coef_, self.n_iter_ = _ridge_regression(
#     783                 X,
#     784                 y,
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\linear_model\_ridge.py in _ridge_regression(X, y, alpha, sample_weight, solver, max_iter, tol, verbose, positive, random_state, return_n_iter, return_intercept, X_scale, X_offset, check_input)
#     597         else:
#     598             try:
# --> 599                 coef = _solve_cholesky(X, y, alpha)
#     600             except linalg.LinAlgError:
#     601                 # use SVD solver if matrix is singular
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\linear_model\_ridge.py in _solve_cholesky(X, y, alpha)
#     155     if one_alpha:
#     156         A.flat[:: n_features + 1] += alpha[0]
# --> 157         return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
#     158     else:
#     159         coefs = np.empty([n_targets, n_features], dtype=X.dtype)
#
# TypeError: solve() got an unexpected keyword argument 'sym_pos'

# %%
# Utilizando o eli5 para explicar o classificador XGBClassifier
# Criando uma instância do eli5 para o classificador
eli5_explainer = eli5.sklearn.Explanation(estimator=xgb.named_steps['estimator'],
                                          vec=xgb.named_steps['vect'])

# Obtendo uma explicação para uma instância de teste (índice 0 neste exemplo)
eli5_explanation = eli5.explain_prediction_text(xgb.named_steps['estimator'], X_test[0], vec=xgb.named_steps['vect'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11724\2187368180.py in <module>
#       1 # Utilizando o eli5 para explicar o classificador XGBClassifier
#       2 # Criando uma instância do eli5 para o classificador
# ----> 3 eli5_explainer = eli5.sklearn.Explanation(estimator=xgb.named_steps['estimator'],
#       4                                           vec=xgb.named_steps['vect'])
#       5
#
# AttributeError: module 'eli5.sklearn' has no attribute 'Explanation'

# %%
def get_classification(X_test):

    return xgb.predict(X_test)

# %%
# Instância do Explainer do SHAP para o modelo treinado
explainer = shap.Explainer(get_classification, X_train)
explainer.shap_values(X_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11724\3457542335.py in <module>
#       1 # Instância do Explainer do SHAP para o modelo treinado
#       2 explainer = shap.Explainer(get_classification, X_train_text)
# ----> 3 explainer.shap_values(list(X_test_text))
#
# D:\Downloads2\Anaconda\download\lib\site-packages\shap\explainers\_permutation.py in shap_values(self, X, npermutations, main_effects, error_bounds, batch_evals, silent)
#     211         warnings.warn("shap_values() is deprecated; use __call__().", DeprecationWarning)
#     212
# --> 213         explanation = self(X, max_evals=npermutations * X.shape[1], main_effects=main_effects)
#     214         return explanation.values
#     215
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
X_test.to_array()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11724\4205620860.py in <module>
# ----> 1 X_test_text.to_array()
#
# D:\Downloads2\Anaconda\download\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'to_array'

# %%
# Instância do Explainer do SHAP para o modelo treinado
explainer = shap.Explainer(xgb.named_steps['estimator'])

# Obtendo as previsões SHAP para as instâncias de teste
shap_values = explainer.shap_values(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11724\2150536062.py in <module>
#       3
#       4 # Obtendo as previsões SHAP para as instâncias de teste
# ----> 5 shap_values = explainer.shap_values(X_test_text)
#
# D:\Downloads2\Anaconda\download\lib\site-packages\shap\explainers\_tree.py in shap_values(self, X, y, tree_limit, approximate, check_additivity, from_call)
#     396                     # Retrieve any DMatrix properties if they have been set on the TreeEnsemble Class
#     397                     dmatrix_props = getattr(self.model, "_xgb_dmatrix_props", {})
# --> 398                     X = xgboost.DMatrix(X, **dmatrix_props)
#     399                 if tree_limit == -1:
#     400                     tree_limit = 0
#
# D:\Downloads2\Anaconda\download\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     618             for k, arg in zip(sig.parameters, args):
#     619                 kwargs[k] = arg
# --> 620             return func(**kwargs)
#     621
#     622         return inner_f
#
# D:\Downloads2\Anaconda\download\lib\site-packages\xgboost\core.py in __init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     741             return
#     742
# --> 743         handle, feature_names, feature_types = dispatch_data_backend(
#     744             data,
#     745             missing=self.missing,
#
# D:\Downloads2\Anaconda\download\lib\site-packages\xgboost\data.py in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical)
#     958                                feature_names, feature_types)
#     959     if _is_pandas_series(data):
# --> 960         return _from_pandas_series(
#     961             data, missing, threads, enable_categorical, feature_names, feature_types
#     962         )
#
# D:\Downloads2\Anaconda\download\lib\site-packages\xgboost\data.py in _from_pandas_series(data, missing, nthread, enable_categorical, feature_names, feature_types)
#     452         is_categorical_dtype(data.dtype) and enable_categorical
#     453     ):
# --> 454         _invalid_dataframe_dtype(data)
#     455     if enable_categorical and is_categorical_dtype(data.dtype):
#     456         data = data.cat.codes
#
# D:\Downloads2\Anaconda\download\lib\site-packages\xgboost\data.py in _invalid_dataframe_dtype(data)
#     268     type_err = "DataFrame.dtypes for data must be int, float, bool or category."
#     269     msg = f"""{type_err} {_ENABLE_CAT_ERR} {err}"""
# --> 270     raise ValueError(msg)
#     271
#     272
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, The experimental DMatrix parameter`enable_categorical` must be set to `True`.

# %%
# Utilizando o eli5 para explicar o classificador XGBClassifier
eli5.show_weights(xgb.named_steps['estimator'], vec=xgb.named_steps['vect'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0385
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 5-c
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.32%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0224
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 7.<span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0.1em" title="A space symbol">&emsp;</span>e
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0165
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 evej
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0152
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 5.<span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0.1em" title="A space symbol">&emsp;</span>a
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.96%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0144
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 7<span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0.1em" title="A space symbol">&emsp;</span>em
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0141
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>6/
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.24%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0138
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 f%
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.25%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0138
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 erpr
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.25%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0138
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ia<span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0.1em" title="A space symbol">&emsp;</span>!
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.36%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0136
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ia<span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0.1em" title="A space symbol">&emsp;</span>-
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.18%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0120
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 60/
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0116
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 epco
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0113
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 5-bb
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0113
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 _p=
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.93%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0105
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 epca
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.96%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0105
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 a:<span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0.1em" title="A space symbol">&emsp;</span>e
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.10%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0102
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 f#pa
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.33%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0098
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ab<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#             </td>
#         </tr>
#
#         <tr style

# %%
type(X_test)
# Out:
# pandas.core.series.Series

# %%
# importing the libraries
import lime
import sklearn.ensemble
from __future__ import print_function
from lime import lime_text
from sklearn.pipeline import make_pipeline
from lime.lime_text import LimeTextExplainer

# converting the vectoriser and model into a pipeline
# this is necessary as LIME takes a model pipeline as an input
#c = make_pipeline(tf, model)

# saving a list of strings version of the X_test object
ls_X_test= list(X_test)

# saving the class names in a dictionary to increase interpretability
class_names = {0: 'a1', 1:'a2', 2: 'a3', 3: 'a4'}

# %%
pd.DataFrame(X_train).columns
# Out:
# Index(['req_text'], dtype='object')

# %%
# sampling data from the training and test set to reduce time-taken
X_train_sample = shap.sample(X_train, 200)
#X_test_sample = shap.sample(X_test_tf, 40)

# %%
# creating the KernelExplainer using the logistic regression model and training sample
SHAP_explainer = shap.TreeExplainer(xgb.predict, X_train_sample)
# calculating the shap values of the test sample using the explainer 
shap_vals = SHAP_explainer.shap_values(X_test)
# Out:
# ---------------------------------------------------------------------------
# InvalidMaskerError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11724\1087326983.py in <module>
#       1 # creating the KernelExplainer using the logistic regression model and training sample
# ----> 2 SHAP_explainer = shap.TreeExplainer(xgb.predict, X_train_sample)
#       3 # calculating the shap values of the test sample using the explainer
#       4 shap_vals = SHAP_explainer.shap_values(X_test_text)
#
# D:\Downloads2\Anaconda\download\lib\site-packages\shap\explainers\_tree.py in __init__(self, model, data, model_output, feature_perturbation, feature_names, approximate, **deprecated_options)
#     125             data = self.masker.data
#     126         elif masker is not None:
# --> 127             raise InvalidMaskerError("Unsupported masker type: %s!" % str(type(self.masker)))
#     128
#     129         if getattr(self.masker, "clustering", None) is not None:
#
# InvalidMaskerError: Unsupported masker type: <class 'pandas.core.series.Series'>!

# %%
# create the LIME explainer
# add the class names for interpretability
LIME_explainer = LimeTextExplainer(class_names=class_names)

# choose a random single prediction
idx = 15
# explain the chosen prediction 
# use the probability results of the logistic regression
# can also add num_features parameter to reduce the number of features explained
LIME_exp = LIME_explainer.explain_instance(ls_X_test[idx], xgb.predict_proba)
# print results
print('Document id: %d' % idx)
print('Tweet: ', ls_X_test[idx])
print('Probability disaster =', xgb.predict_proba([ls_X_test[idx]]).round(3)[0,1])
print('True class: %s' % class_names.get(list(y_test)[idx]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11724\4256509238.py in <module>
#       8 # use the probability results of the logistic regression
#       9 # can also add num_features parameter to reduce the number of features explained
# ---> 10 LIME_exp = LIME_explainer.explain_instance(ls_X_test[idx], xgb.predict_proba)
#      11 # print results
#      12 print('Document id: %d' % idx)
#
# D:\Downloads2\Anaconda\download\lib\site-packages\lime\lime_text.py in explain_instance(self, text_instance, classifier_fn, labels, top_labels, num_features, num_samples, distance_metric, model_regressor)
#     427             (ret_exp.intercept[label],
#     428              ret_exp.local_exp[label],
# --> 429              ret_exp.score, ret_exp.local_pred) = self.base.explain_instance_with_data(
#     430                 data, yss, distances, label, num_features,
#     431                 model_regressor=model_regressor,
#
# D:\Downloads2\Anaconda\download\lib\site-packages\lime\lime_base.py in explain_instance_with_data(self, neighborhood_data, neighborhood_labels, distances, label, num_features, feature_selection, model_regressor)
#     181         weights = self.kernel_fn(distances)
#     182         labels_column = neighborhood_labels[:, label]
# --> 183         used_features = self.feature_selection(neighborhood_data,
#     184                                                labels_column,
#     185                                                weights,
#
# D:\Downloads2\Anaconda\download\lib\site-packages\lime\lime_base.py in feature_selection(self, data, labels, weights, num_features, method)
#     132             else:
#     133                 n_method = 'highest_weights'
# --> 134             return self.feature_selection(data, labels, weights,
#     135                                           num_features, n_method)
#     136
#
# D:\Downloads2\Anaconda\download\lib\site-packages\lime\lime_base.py in feature_selection(self, data, labels, weights, num_features, method)
#      78             clf = Ridge(alpha=0.01, fit_intercept=True,
#      79                         random_state=self.random_state)
# ---> 80             clf.fit(data, labels, sample_weight=weights)
#      81
#      82             coef = clf.coef_
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\linear_model\_ridge.py in fit(self, X, y, sample_weight)
#    1009             y_numeric=True,
#    1010         )
# -> 1011         return super().fit(X, y, sample_weight=sample_weight)
#    1012
#    1013
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\linear_model\_ridge.py in fit(self, X, y, sample_weight)
#     780                 params = {}
#     781
# --> 782             self.coef_, self.n_iter_ = _ridge_regression(
#     783                 X,
#     784                 y,
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\linear_model\_ridge.py in _ridge_regression(X, y, alpha, sample_weight, solver, max_iter, tol, verbose, positive, random_state, return_n_iter, return_intercept, X_scale, X_offset, check_input)
#     597         else:
#     598             try:
# --> 599                 coef = _solve_cholesky(X, y, alpha)
#     600             except linalg.LinAlgError:
#     601                 # use SVD solver if matrix is singular
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\linear_model\_ridge.py in _solve_cholesky(X, y, alpha)
#     155     if one_alpha:
#     156         A.flat[:: n_features + 1] += alpha[0]
# --> 157         return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
#     158     else:
#     159         coefs = np.empty([n_targets, n_features], dtype=X.dtype)
#
# TypeError: solve() got an unexpected keyword argument 'sym_pos'

# %%
from eli5.lime import TextExplainer

# %%
xgb.predict_proba
# Out:
# <function sklearn.pipeline.Pipeline.predict_proba(self, X, **predict_proba_params)>

# %%
exp = TextExplainer(random_state=42)

# %%
X_test.values[1]
# Out:
# 'Bom dia! Gostaria de saber se a instituição possui código de vaga para Assistente em Administração no campus situado em Rio das Ostras? Se houver, esse código de vaga está comprometido com concurso público ou poderá ser utilizado por redistribuição? Desde já, obrigado!'

# %%
exp.fit(X_test.values[0], xgb.predict_proba)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# D:\Downloads2\Anaconda\download\lib\site-packages\IPython\core\formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\base.py in _repr_mimebundle_(self, **kwargs)
#     612     def _repr_mimebundle_(self, **kwargs):
#     613         """Mime bundle used by jupyter kernels to display estimator"""
# --> 614         output = {"text/plain": repr(self)}
#     615         if get_config()["display"] == "diagram":
#     616             output["text/html"] = estimator_html_repr(self)
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\base.py in __repr__(self, N_CHAR_MAX)
#     277         )
#     278
# --> 279         repr_ = pp.pformat(self)
#     280
#     281         # Use bruteforce ellipsis when there are a lot of non-blank characters
#
# D:\Downloads2\Anaconda\download\lib\pprint.py in pformat(self, object)
#     151     def pformat(self, object):
#     152         sio = _StringIO()
# --> 153         self._format(object, sio, 0, 0, {}, 0)
#     154         return sio.getvalue()
#     155
#
# D:\Downloads2\Anaconda\download\lib\pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     168             self._readable = False
#     169             return
# --> 170         rep = self._repr(object, context, level)
#     171         max_width = self._width - indent - allowance
#     172         if len(rep) > max_width:
#
# D:\Downloads2\Anaconda\download\lib\pprint.py in _repr(self, object, context, level)
#     429
#     430     def _repr(self, object, context, level):
# --> 431         repr, readable, recursive = self.format(object, context.copy(),
#     432                                                 self._depth, level)
#     433         if not readable:
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\utils\_pprint.py in format(self, object, context, maxlevels, level)
#     187
#     188     def format(self, object, context, maxlevels, level):
# --> 189         return _safe_repr(
#     190             object, context, maxlevels, level, changed_only=self._changed_only
#     191         )
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     450                 k, context, maxlevels, level, changed_only=changed_only
#     451             )
# --> 452             vrepr, vreadable, vrecur = saferepr(
#     453                 v, context, maxlevels, level, changed_only=changed_only
#     454             )
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     438         recursive = False
#     439         if changed_only:
# --> 440             params = _changed_params(object)
#     441         else:
#     442             params = object.get_params(deep=False)
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\utils\_pprint.py in _changed_params(estimator)
#      91     estimator with non-default values."""
#      92
# ---> 93     params = estimator.get_params(deep=False)
#      94     init_func = getattr(estimator.__init__, "deprecated_original", estimator.__init__)
#      95     init_params = inspect.signature(init_func).parameters
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\base.py in get_params(self, deep)
#     208         out = dict()
#     209         for key in self._get_param_names():
# --> 210             value = getattr(self, key)
#     211             if deep and hasattr(value, "get_params"):
#     212                 deep_items = value.get_params().items()
#
# AttributeError: 'MaskingTextSamplers' object has no attribute 'sampler_params'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# D:\Downloads2\Anaconda\download\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# D:\Downloads2\Anaconda\download\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# D:\Downloads2\Anaconda\download\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
#     698     """A pprint that just redirects to the normal repr function."""
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#     702     with p.group():
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\base.py in __repr__(self, N_CHAR_MAX)
#     277         )
#     278
# --> 279         repr_ = pp.pformat(self)
#     280
#     281         # Use bruteforce ellipsis when there are a lot of non-blank characters
#
# D:\Downloads2\Anaconda\download\lib\pprint.py in pformat(self, object)
#     151     def pformat(self, object):
#     152         sio = _StringIO()
# --> 153         self._format(object, sio, 0, 0, {}, 0)
#     154         return sio.getvalue()
#     155
#
# D:\Downloads2\Anaconda\download\lib\pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     168             self._readable = False
#     169             return
# --> 170         rep = self._repr(object, context, level)
#     171         max_width = self._width - indent - allowance
#     172         if len(rep) > max_width:
#
# D:\Downloads2\Anaconda\download\lib\pprint.py in _repr(self, object, context, level)
#     429
#     430     def _repr(self, object, context, level):
# --> 431         repr, readable, recursive = self.format(object, context.copy(),
#     432                                                 self._depth, level)
#     433         if not readable:
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\utils\_pprint.py in format(self, object, context, maxlevels, level)
#     187
#     188     def format(self, object, context, maxlevels, level):
# --> 189         return _safe_repr(
#     190             object, context, maxlevels, level, changed_only=self._changed_only
#     191         )
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     450                 k, context, maxlevels, level, changed_only=changed_only
#     451             )
# --> 452             vrepr, vreadable, vrecur = saferepr(
#     453                 v, context, maxlevels, level, changed_only=changed_only
#     454             )
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     438         recursive = False
#     439         if changed_only:
# --> 440             params = _changed_params(object)
#     441         else:
#     442             params = object.get_params(deep=False)
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\utils\_pprint.py in _changed_params(estimator)
#      91     estimator with non-default values."""
#      92
# ---> 93     params = estimator.get_params(deep=False)
#      94     init_func = getattr(estimator.__init__, "deprecated_original", estimator.__init__)
#      95     init_params = inspect.signature(init_func).parameters
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\base.py in get_params(self, deep)
#     208         out = dict()
#     209         for key in self._get_param_names():
# --> 210             value = getattr(self, key)
#     211             if deep and hasattr(value, "get_params"):
#     212                 deep_items = value.get_params().items()
#
# AttributeError: 'MaskingTextSamplers' object has no attribute 'sampler_params'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# D:\Downloads2\Anaconda\download\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\base.py in _repr_html_inner(self)
#     608         on `get_config()["display"]`.
#     609         """
# --> 610         return estimator_html_repr(self)
#     611
#     612     def _repr_mimebundle_(self, **kwargs):
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\utils\_estimator_html_repr.py in estimator_html_repr(estimator)
#     361         style_template = Template(_STYLE)
#     362         style_with_id = style_template.substitute(id=container_id)
# --> 363         estimator_str = str(estimator)
#     364
#     365         # The fallback message is shown by default and loading the CSS sets
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\base.py in __repr__(self, N_CHAR_MAX)
#     277         )
#     278
# --> 279         repr_ = pp.pformat(self)
#     280
#     281         # Use bruteforce ellipsis when there are a lot of non-blank characters
#
# D:\Downloads2\Anaconda\download\lib\pprint.py in pformat(self, object)
#     151     def pformat(self, object):
#     152         sio = _StringIO()
# --> 153         self._format(object, sio, 0, 0, {}, 0)
#     154         return sio.getvalue()
#     155
#
# D:\Downloads2\Anaconda\download\lib\pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     168             self._readable = False
#     169             return
# --> 170         rep = self._repr(object, context, level)
#     171         max_width = self._width - indent - allowance
#     172         if len(rep) > max_width:
#
# D:\Downloads2\Anaconda\download\lib\pprint.py in _repr(self, object, context, level)
#     429
#     430     def _repr(self, object, context, level):
# --> 431         repr, readable, recursive = self.format(object, context.copy(),
#     432                                                 self._depth, level)
#     433         if not readable:
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\utils\_pprint.py in format(self, object, context, maxlevels, level)
#     187
#     188     def format(self, object, context, maxlevels, level):
# --> 189         return _safe_repr(
#     190             object, context, maxlevels, level, changed_only=self._changed_only
#     191         )
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     450                 k, context, maxlevels, level, changed_only=changed_only
#     451             )
# --> 452             vrepr, vreadable, vrecur = saferepr(
#     453                 v, context, maxlevels, level, changed_only=changed_only
#     454             )
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\utils\_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     438         recursive = False
#     439         if changed_only:
# --> 440             params = _changed_params(object)
#     441         else:
#     442             params = object.get_params(deep=False)
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\utils\_pprint.py in _changed_params(estimator)
#      91     estimator with non-default values."""
#      92
# ---> 93     params = estimator.get_params(deep=False)
#      94     init_func = getattr(estimator.__init__, "deprecated_original", estimator.__init__)
#      95     init_params = inspect.signature(init_func).parameters
#
# D:\Downloads2\Anaconda\download\lib\site-packages\sklearn\base.py in get_params(self, deep)
#     208         out = dict()
#     209         for key in self._get_param_names():
# --> 210             value = getattr(self, key)
#     211             if deep and hasattr(value, "get_params"):
#     212                 deep_items = value.get_params().items()
#
# AttributeError: 'MaskingTextSamplers' object has no attribute 'sampler_params'

# %%
explainer = shap.TreeExplainer(xgb.named_steps['estimator'])
explainer.shap_values(X_test[:3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11724\3894077670.py in <module>
#       1 explainer = shap.TreeExplainer(xgb.named_steps['estimator'])
# ----> 2 explainer.shap_values(X_test_text[:3])
#
# D:\Downloads2\Anaconda\download\lib\site-packages\shap\explainers\_tree.py in shap_values(self, X, y, tree_limit, approximate, check_additivity, from_call)
#     396                     # Retrieve any DMatrix properties if they have been set on the TreeEnsemble Class
#     397                     dmatrix_props = getattr(self.model, "_xgb_dmatrix_props", {})
# --> 398                     X = xgboost.DMatrix(X, **dmatrix_props)
#     399                 if tree_limit == -1:
#     400                     tree_limit = 0
#
# D:\Downloads2\Anaconda\download\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     618             for k, arg in zip(sig.parameters, args):
#     619                 kwargs[k] = arg
# --> 620             return func(**kwargs)
#     621
#     622         return inner_f
#
# D:\Downloads2\Anaconda\download\lib\site-packages\xgboost\core.py in __init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     741             return
#     742
# --> 743         handle, feature_names, feature_types = dispatch_data_backend(
#     744             data,
#     745             missing=self.missing,
#
# D:\Downloads2\Anaconda\download\lib\site-packages\xgboost\data.py in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical)
#     958                                feature_names, feature_types)
#     959     if _is_pandas_series(data):
# --> 960         return _from_pandas_series(
#     961             data, missing, threads, enable_categorical, feature_names, feature_types
#     962         )
#
# D:\Downloads2\Anaconda\download\lib\site-packages\xgboost\data.py in _from_pandas_series(data, missing, nthread, enable_categorical, feature_names, feature_types)
#     452         is_categorical_dtype(data.dtype) and enable_categorical
#     453     ):
# --> 454         _invalid_dataframe_dtype(data)
#     455     if enable_categorical and is_categorical_dtype(data.dtype):
#     456         data = data.cat.codes
#
# D:\Downloads2\Anaconda\download\lib\site-packages\xgboost\data.py in _invalid_dataframe_dtype(data)
#     268     type_err = "DataFrame.dtypes for data must be int, float, bool or category."
#     269     msg = f"""{type_err} {_ENABLE_CAT_ERR} {err}"""
# --> 270     raise ValueError(msg)
#     271
#     272
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, The experimental DMatrix parameter`enable_categorical` must be set to `True`.

# %%
eli5.show_weights(xgb, top=9)
# Out:
# Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11724\129793378.py in <module>
# ----> 1 eli5.show_weights(xgb, top=9)
#
# D:\Downloads2\Anaconda\download\lib\site-packages\eli5\ipython.py in show_weights(estimator, **kwargs)
#     128     """
#     129     format_kwargs, explain_kwargs = _split_kwargs(kwargs)
# --> 130     expl = explain_weights(estimator, **explain_kwargs)
#     131     _set_html_kwargs_defaults(format_kwargs)
#     132     html = format_as_html(expl, **format_kwargs)
#
# D:\Downloads2\Anaconda\download\lib\functools.py in wrapper(*args, **kw)
#     886                             '1 positional argument')
#     887
# --> 888         return dispatch(args[0].__class__)(*args, **kw)
#     889
#     890     funcname = getattr(func, '__name__', 'singledispatch function')
#
# D:\Downloads2\Anaconda\download\lib\site-packages\eli5\sklearn\explain_weights.py in explain_weights_pipeline(estimator, feature_names, **kwargs)
#     474     if 'vec' in kwargs:
#     475         feature_names = get_feature_names(feature_names, vec=kwargs.pop('vec'))
# --> 476     feature_names = transform_feature_names(transform_pipeline, feature_names)
#     477     out = explain_weights(last_estimator,
#     478                           feature_names=feature_names,
#
# D:\Downloads2\Anaconda\download\lib\functools.py in wrapper(*args, **kw)
#     886                             '1 positional argument')
#     887
# --> 888         return dispatch(args[0].__class__)(*args, **kw)
#     889
#     890     funcname = getattr(func, '__name__', 'singledispatch function')
#
# D:\Downloads2\Anaconda\download\lib\site-packages\eli5\sklearn\transform.py in _pipeline_names(est, in_names)
#      59     for name, trans in est.steps:
#      60         if trans is not None:
# ---> 61             names = transform_feature_names(trans, names)
#      62     return names
#      63
#
# D:\Downloads2\Anaconda\download\lib\functools.py in wrapper(*args, **kw)
#     886                             '1 positional argument')
#     887
# --> 888         return dispatch(args[0].__class__)(*args, **kw)
#     889
#     890     funcname = getattr(func, '__name__', 'singledispatch function')
#
# D:\Downloads2\Anaconda\download\lib\site-packages\eli5\transform.py in transform_feature_names(transformer, in_names)
#      31     if hasattr(transformer, 'get_feature_names'):
#      32         return transformer.get_feature_names()
# ---> 33     raise NotImplementedError('transform_feature_names not available for '
#      34                               '{}'.format(transformer))
#
# NotImplementedError: transform_feature_names not available for RandomOverSampler(random_state=42)

# %%
def get_classification(X_test):

    return text_clf.predict(X_test)

# %%
get_classification

# %%
text_clf = pipeline.set_params(**best_params)

# %%
text_clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vect', TfidfVectorizer(ngram_range=(1, 3))),
#                 ('scaling', MaxAbsScaler()),
#                 ('selection', SelectPercentile(percentile=100)),
#                 ('estimator', MultinomialNB(alpha=0.3, fit_prior=False))])

# %%
y_pred = text_clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.4951219512195122

# %%
# Utilizando o eli5 para explicar o classificador MultinomialNB
eli5.show_weights(pipeline.named_steps['estimator'], vec=pipeline.named_steps['vect'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <div style="background-color: #fdd; padding: 0.5em;">
#         Error: estimator MultinomialNB(alpha=0.3, fit_prior=False) is not supported
#     </div>

# %%
eli5.show_weights(text_clf, top=9)
# Out:
# Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <div style="background-color: #fdd; padding: 0.5em;">
#         Error: estimator MultinomialNB(alpha=0.3, fit_prior=False) is not supported
#     </div>

# %%
X_test.iloc[:3]
# Out:
# 6086    BOM DIA, PRECISO DE INFORMAÇÕES JUNTO AO ORGÃO...
# 5363    Bom dia! Gostaria de saber se a instituição po...
# 1334    Boa noite fia a ultima prova da CONAB - ASSIST...
# Name: req_text, dtype: object

# %%
# Instância do Explainer do SHAP para o modelo treinado
explainer = shap.Explainer(get_classification, X_train)
explainer.shap_values(X_test.iloc[:3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1840\1057536006.py in <module>
#       1 # Instância do Explainer do SHAP para o modelo treinado
#       2 explainer = shap.Explainer(get_classification, X_train_text)
# ----> 3 explainer.shap_values(X_test_text.iloc[:3])
#
# D:\Downloads2\Anaconda\download\lib\site-packages\shap\explainers\_permutation.py in shap_values(self, X, npermutations, main_effects, error_bounds, batch_evals, silent)
#     211         warnings.warn("shap_values() is deprecated; use __call__().", DeprecationWarning)
#     212
# --> 213         explanation = self(X, max_evals=npermutations * X.shape[1], main_effects=main_effects)
#     214         return explanation.values
#     215
#
# IndexError: tuple index out of range
